# %% [markdown]
# ## Machine Learning with Label Trained Data

# %% [markdown]
# Collecting and Storing Data is done by Data Engineers
# Explore, Aggregate/Label and Learn, Optimise using data done by Data Scientists
#
# Data Mining + Computer Science = Data Science

# %% [markdown]
# Workflow for Data Scientist:
# 1. Formulate the Question that they are looking to answer
#     -Look at related factors.
#
# 2. Gather Data
#
# 3. Clean Data
#
# 4. Explore & Visualise
#
# 5. Train Algorithm
#
# 6. Evaluate Results -- Check Accuracy

# %% [markdown]
# There is an Independent Variable a.k.a Target
# And Dependent Variable a.k.a Feature
#
# Independent Variable (x) is the one manipulated. And Dependent Variable (y) is the one that depends on independent variable.
#
# in data science instead of y = mx + c for linear regression it will be :
#
# hθ(x) =  = θ0  + θ1 x
#
# therefore θ0 is the c
# and θ1 is the m
# and hθ(x)  is the y a.k.a hypothesis
#
# Residuals help to decide the best fitted line.

# %%
from IPython.display import Image
Image(filename='2020-05-21-10-18-38.png')

# %% [markdown]
# ### Import Libraries

# %%
import pandas
from pandas import DataFrame

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %% [markdown]
# ## data.describe()

# %%
X = DataFrame(data, columns = ['production_budget_usd'])
y = DataFrame(data, columns = ['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y,alpha = 0.3) #alpha changes transparency
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000) #limits 
plt.xlim(0,450000000)
plt.show()

# %%
regr = LinearRegression()
regr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Slope Coefficient:

# %%
regr.coef_ #theta_1
# Out:
# array([[3.11150918]])

# %% [markdown]
# ### Intercept:

# %%
regr.intercept_ #theta_0
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y,alpha = 0.3) #alpha changes transparency
plt.plot(X, regr.predict(X), color = 'red', linewidth = 4)

plt.title('Film Cost vs Global Revenue')

plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')

plt.ylim(0,3000000000) #limits 
plt.xlim(0,450000000)

plt.style.use('fivethirtyeight')
plt.show()

# %%
type(regr.intercept_)
# Out:
# numpy.ndarray

# %% [markdown]
# Take note that lists consists of all types, but array elemets all of the same type in a list.
